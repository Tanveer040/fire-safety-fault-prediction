# %%
import pyodbc

# %%
pyodbc.drivers()
# Out:
# ['SQL Server',
#  'ODBC Driver 17 for SQL Server',
#  'Microsoft Access Driver (*.mdb, *.accdb)',
#  'Microsoft Excel Driver (*.xls, *.xlsx, *.xlsm, *.xlsb)',
#  'Microsoft Access Text Driver (*.txt, *.csv)',
#  'Microsoft Access dBASE Driver (*.dbf, *.ndx, *.mdx)']

# %%
from sqlalchemy import create_engine
import urllib

server = 'DESKTOP-6MJU11J'
database = 'iotdata_events' 

params = urllib.parse.quote_plus(
    f"DRIVER={{ODBC Driver 17 for SQL Server}};"
    f"SERVER={server};"
    f"DATABASE={database};"
    f"Trusted_Connection=yes;"
)

engine = create_engine(f"mssql+pyodbc:///?odbc_connect={params}")

# Example test

with engine.connect() as conn:
    result = conn.execute("SELECT GETDATE()")
    for row in result:
        print(row)
# Out:
# (datetime.datetime(2025, 4, 24, 8, 57, 14, 723000),)

# %%
# Load data
import pandas as pd
table = "FireEvents" 
df = pd.read_sql(f"SELECT * FROM {table}", engine)
print(df.shape)
df.head()
# Out:
# (940083, 12)
#                   ADDEDAT             COMPANYID            DETECTORID  \
# 0 2024-08-07 17:56:29.842  n7Tktl6xJA2qDV8RcMpf  NflPelhGxDx2yF20gn7Y
# 1 2024-08-14 10:49:42.359  n7Tktl6xJA2qDV8RcMpf  yPHI0SRu7cRZ2YNmfDPG
# 2 2024-09-03 17:05:31.186  n7Tktl6xJA2qDV8RcMpf  hsBtiG1y58ChVue6Mstj
# 3 2025-01-09 03:27:26.923  n7Tktl6xJA2qDV8RcMpf  NflPelhGxDx2yF20gn7Y
# 4 2024-08-28 12:18:26.508  n7Tktl6xJA2qDV8RcMpf  5r2EosP2Vnb9cMJsQUA9
#
#   DURATION                    ID  \
# 0     None  O0uFfYqPcl4PMU3uXxpe
# 1     None  xByYZSjb4uJqpLZkLwCa
# 2     None  EEL0bHavix9GmwdKvd0p
# 3     None  4RVo9ZSGMWFzHhvtUDcd
# 4     None  91S1PYh6HlGxdBqqMf9S
#
#                                           IDENTIFIER              RECORDEDAT  \
# 0  {\n  "device": "172",\n  "group": null,\n  "lo... 2024-08-07 17:56:28.957
# 1  {\n  "device": "191",\n  "group": null,\n  "lo... 2024-08-14 10:49:40.278
# 2  {\n  "device": "92",\n  "group": null,\n  "loo... 2024-09-03 17:05:16.008
# 3  {\n  "device": "172",\n  "group": null,\n  "lo... 2025-01-09 03:27:24.867
# 4  {\n  "device": "136",\n  "group": null,\n  "lo... 2024-08-28 12:18:25.776
#
#                  SITEID                                              STATE  \
# 0  DO05xnc9uzEwZ1OvRGSP  {\n  "alarm": "off",\n  "fault": "off",\n  "fa...
# 1  DO05xnc9uzEwZ1OvRGSP  {\n  "alarm": "off",\n  "fault": "off",\n  "fa...
# 2  DO05xnc9uzEwZ1OvRGSP  {\n  "alarm": "unknown",\n  "fault": "on",\n  ...
# 3  DO05xnc9uzEwZ1OvRGSP  {\n  "alarm": "off",\n  "fault": "off",\n  "fa...
# 4  DO05xnc9uzEwZ1OvRGSP  {\n  "alarm": "unknown",\n  "fault": "on",\n  ...
#
#    SYSTEMGENERATED  WILLSHOWINAPP  \
# 0            False           True
# 1            False           True
# 2            False           True
# 3            False           True
# 4            False           True
#
#                                              MESSAGE
# 0  {\n  "descriptor": "initialising rl03 back of ...
# 1  {\n  "descriptor": "normal rl03 smoke zone 2 r...
# 2  {\n  "descriptor": "device missing rl06 smoke ...
# 3  {\n  "descriptor": "normal rl03 back of house ...
# 4  {\n  "descriptor": "device missing node 1 ffcp...

# %%
import json

# %%
# Step 2: Load data from the SQL Server into a DataFrame
#table = "FireEvents"  # Name of your SQL table
##df = pd.read_sql(f"SELECT * FROM {table}", engine)

# Display the shape (rows, columns) of the loaded DataFrame
print("Original DataFrame shape:", df.shape)

# Show the first few rows to preview the structure
##df.head()
# Out:
# Original DataFrame shape: (940083, 12)

# %%
# Step 3: Check structure of one JSON entry to verify format
print("Sample JSON from EventDetails column:")
print(df['IDENTIFIER'].iloc[0])

# Step 3: Check structure of one JSON entry to verify format
print("Sample JSON from SITE column:")
print(df['STATE'].iloc[0])

# Step 3: Check structure of one JSON entry to verify format
print("Sample JSON from MESSAGE column:")
print(df['MESSAGE'].iloc[0])

# Step 3: Check structure of one JSON entry to verify format
print("Sample JSON from DURATION column:")
print(df['DURATION'].iloc[0])
# Out:
# Sample JSON from EventDetails column:
# {
#   "device": "172",
#   "group": null,
#   "loop": "26",
#   "module": null,
#   "node": "9",
#   "sensor": "0",
#   "zone": "109"
# }
# Sample JSON from SITE column:
# {
#   "alarm": "off",
#   "fault": "off",
#   "faultCode": null,
#   "isolate": "off",
#   "preAlarm": "off",
#   "sensor": null
# }
# Sample JSON from MESSAGE column:
# {
#   "descriptor": "initialising rl03 back of house rl03 z1 corridor mcp 3012a",
#   "detector": "Z109N9L26D172S0",
#   "notification": "z109n9l26d172s0 - m214 - SC1 retail",
#   "raw": "initialising rl03 back of house rl03 z1 corridor mcp 3012a",
#   "state": "NNNN"
# }
# Sample JSON from DURATION column:
# None

# %%
df=df.join(df['IDENTIFIER'].apply(json.loads).apply(pd.Series))

# %%
print(df.shape)
df.head()
# Out:
# (940083, 19)
#                   ADDEDAT             COMPANYID            DETECTORID  \
# 0 2024-08-07 17:56:29.842  n7Tktl6xJA2qDV8RcMpf  NflPelhGxDx2yF20gn7Y
# 1 2024-08-14 10:49:42.359  n7Tktl6xJA2qDV8RcMpf  yPHI0SRu7cRZ2YNmfDPG
# 2 2024-09-03 17:05:31.186  n7Tktl6xJA2qDV8RcMpf  hsBtiG1y58ChVue6Mstj
# 3 2025-01-09 03:27:26.923  n7Tktl6xJA2qDV8RcMpf  NflPelhGxDx2yF20gn7Y
# 4 2024-08-28 12:18:26.508  n7Tktl6xJA2qDV8RcMpf  5r2EosP2Vnb9cMJsQUA9
#
#   DURATION                    ID  \
# 0     None  O0uFfYqPcl4PMU3uXxpe
# 1     None  xByYZSjb4uJqpLZkLwCa
# 2     None  EEL0bHavix9GmwdKvd0p
# 3     None  4RVo9ZSGMWFzHhvtUDcd
# 4     None  91S1PYh6HlGxdBqqMf9S
#
#                                           IDENTIFIER              RECORDEDAT  \
# 0  {\n  "device": "172",\n  "group": null,\n  "lo... 2024-08-07 17:56:28.957
# 1  {\n  "device": "191",\n  "group": null,\n  "lo... 2024-08-14 10:49:40.278
# 2  {\n  "device": "92",\n  "group": null,\n  "loo... 2024-09-03 17:05:16.008
# 3  {\n  "device": "172",\n  "group": null,\n  "lo... 2025-01-09 03:27:24.867
# 4  {\n  "device": "136",\n  "group": null,\n  "lo... 2024-08-28 12:18:25.776
#
#                  SITEID                                              STATE  \
# 0  DO05xnc9uzEwZ1OvRGSP  {\n  "alarm": "off",\n  "fault": "off",\n  "fa...
# 1  DO05xnc9uzEwZ1OvRGSP  {\n  "alarm": "off",\n  "fault": "off",\n  "fa...
# 2  DO05xnc9uzEwZ1OvRGSP  {\n  "alarm": "unknown",\n  "fault": "on",\n  ...
# 3  DO05xnc9uzEwZ1OvRGSP  {\n  "alarm": "off",\n  "fault": "off",\n  "fa...
# 4  DO05xnc9uzEwZ1OvRGSP  {\n  "alarm": "unknown",\n  "fault": "on",\n  ...
#
#    SYSTEMGENERATED  WILLSHOWINAPP  \
# 0            False           True
# 1            False           True
# 2            False           True
# 3            False           True
# 4            False           True
#
#                                              MESSAGE device group loop module  \
# 0  {\n  "descriptor": "initialising rl03 back of ...    172  None   26   None
# 1  {\n  "descriptor": "normal rl03 smoke zone 2 r...    191  None   26   None
# 2  {\n  "descriptor": "device missing rl06 smoke ...     92  None   13   None
# 3  {\n  "descriptor": "normal rl03 back of house ...    172  None   26   None
# 4  {\n  "descriptor": "device missing node 1 ffcp...    136  None    3   None
#
#   node sensor zone
# 0    9      0  109
# 1    9      0  102
# 2    5      0  191
# 3    9      0  109
# 4    1      0  801

# %%
df = df.join(df['STATE'].apply(json.loads).apply(pd.Series), rsuffix='_from_state')

# %%
print(df.shape)
df.head()
# Out:
# (940083, 25)
#                   ADDEDAT             COMPANYID            DETECTORID  \
# 0 2024-08-07 17:56:29.842  n7Tktl6xJA2qDV8RcMpf  NflPelhGxDx2yF20gn7Y
# 1 2024-08-14 10:49:42.359  n7Tktl6xJA2qDV8RcMpf  yPHI0SRu7cRZ2YNmfDPG
# 2 2024-09-03 17:05:31.186  n7Tktl6xJA2qDV8RcMpf  hsBtiG1y58ChVue6Mstj
# 3 2025-01-09 03:27:26.923  n7Tktl6xJA2qDV8RcMpf  NflPelhGxDx2yF20gn7Y
# 4 2024-08-28 12:18:26.508  n7Tktl6xJA2qDV8RcMpf  5r2EosP2Vnb9cMJsQUA9
#
#   DURATION                    ID  \
# 0     None  O0uFfYqPcl4PMU3uXxpe
# 1     None  xByYZSjb4uJqpLZkLwCa
# 2     None  EEL0bHavix9GmwdKvd0p
# 3     None  4RVo9ZSGMWFzHhvtUDcd
# 4     None  91S1PYh6HlGxdBqqMf9S
#
#                                           IDENTIFIER              RECORDEDAT  \
# 0  {\n  "device": "172",\n  "group": null,\n  "lo... 2024-08-07 17:56:28.957
# 1  {\n  "device": "191",\n  "group": null,\n  "lo... 2024-08-14 10:49:40.278
# 2  {\n  "device": "92",\n  "group": null,\n  "loo... 2024-09-03 17:05:16.008
# 3  {\n  "device": "172",\n  "group": null,\n  "lo... 2025-01-09 03:27:24.867
# 4  {\n  "device": "136",\n  "group": null,\n  "lo... 2024-08-28 12:18:25.776
#
#                  SITEID                                              STATE  \
# 0  DO05xnc9uzEwZ1OvRGSP  {\n  "alarm": "off",\n  "fault": "off",\n  "fa...
# 1  DO05xnc9uzEwZ1OvRGSP  {\n  "alarm": "off",\n  "fault": "off",\n  "fa...
# 2  DO05xnc9uzEwZ1OvRGSP  {\n  "alarm": "unknown",\n  "fault": "on",\n  ...
# 3  DO05xnc9uzEwZ1OvRGSP  {\n  "alarm": "off",\n  "fault": "off",\n  "fa...
# 4  DO05xnc9uzEwZ1OvRGSP  {\n  "alarm": "unknown",\n  "fault": "on",\n  ...
#
#    SYSTEMGENERATED  ...  module node sensor zone    alarm fault  \
# 0            False  ...    None    9      0  109      off   off
# 1            False  ...    None    9      0  102      off   off
# 2            False  ...    None    5      0  191  unknown    on
# 3            False  ...    None    9      0  109      off   off
# 4            False  ...    None    1      0  801  unknown    on
#
#                                         faultCode  isolate preAlarm  \
# 0                                            None      off      off
# 1                                            None      off      off
# 2  {'panel': 'AXIS', 'text': None, 'value': None}  unknown  unknown
# 3                                            None      off      off
# 4  {'panel': 'AXIS', 'text': None, 'value': None}  unknown  unknown
#
#   sensor_from_state
# 0              None
# 1              None
# 2              None
# 3              None
# 4              None
#
# [5 rows x 25 columns]

# %%
df=df.join(df['MESSAGE'].apply(json.loads).apply(pd.Series))

# %%
print(df.shape)
df.head()
# Out:
# (940083, 30)
#                   ADDEDAT             COMPANYID            DETECTORID  \
# 0 2024-08-07 17:56:29.842  n7Tktl6xJA2qDV8RcMpf  NflPelhGxDx2yF20gn7Y
# 1 2024-08-14 10:49:42.359  n7Tktl6xJA2qDV8RcMpf  yPHI0SRu7cRZ2YNmfDPG
# 2 2024-09-03 17:05:31.186  n7Tktl6xJA2qDV8RcMpf  hsBtiG1y58ChVue6Mstj
# 3 2025-01-09 03:27:26.923  n7Tktl6xJA2qDV8RcMpf  NflPelhGxDx2yF20gn7Y
# 4 2024-08-28 12:18:26.508  n7Tktl6xJA2qDV8RcMpf  5r2EosP2Vnb9cMJsQUA9
#
#   DURATION                    ID  \
# 0     None  O0uFfYqPcl4PMU3uXxpe
# 1     None  xByYZSjb4uJqpLZkLwCa
# 2     None  EEL0bHavix9GmwdKvd0p
# 3     None  4RVo9ZSGMWFzHhvtUDcd
# 4     None  91S1PYh6HlGxdBqqMf9S
#
#                                           IDENTIFIER              RECORDEDAT  \
# 0  {\n  "device": "172",\n  "group": null,\n  "lo... 2024-08-07 17:56:28.957
# 1  {\n  "device": "191",\n  "group": null,\n  "lo... 2024-08-14 10:49:40.278
# 2  {\n  "device": "92",\n  "group": null,\n  "loo... 2024-09-03 17:05:16.008
# 3  {\n  "device": "172",\n  "group": null,\n  "lo... 2025-01-09 03:27:24.867
# 4  {\n  "device": "136",\n  "group": null,\n  "lo... 2024-08-28 12:18:25.776
#
#                  SITEID                                              STATE  \
# 0  DO05xnc9uzEwZ1OvRGSP  {\n  "alarm": "off",\n  "fault": "off",\n  "fa...
# 1  DO05xnc9uzEwZ1OvRGSP  {\n  "alarm": "off",\n  "fault": "off",\n  "fa...
# 2  DO05xnc9uzEwZ1OvRGSP  {\n  "alarm": "unknown",\n  "fault": "on",\n  ...
# 3  DO05xnc9uzEwZ1OvRGSP  {\n  "alarm": "off",\n  "fault": "off",\n  "fa...
# 4  DO05xnc9uzEwZ1OvRGSP  {\n  "alarm": "unknown",\n  "fault": "on",\n  ...
#
#    SYSTEMGENERATED  ...  fault  \
# 0            False  ...    off
# 1            False  ...    off
# 2            False  ...     on
# 3            False  ...    off
# 4            False  ...     on
#
#                                         faultCode  isolate preAlarm  \
# 0                                            None      off      off
# 1                                            None      off      off
# 2  {'panel': 'AXIS', 'text': None, 'value': None}  unknown  unknown
# 3                                            None      off      off
# 4  {'panel': 'AXIS', 'text': None, 'value': None}  unknown  unknown
#
#   sensor_from_state                                         descriptor  \
# 0              None  initialising rl03 back of house rl03 z1 corrid...
# 1              None        normal rl03 smoke zone 2 rl03 sz2 s3016 ysl
# 2              None  device missing rl06 smoke zone 1 rl06 sz1 77c ...
# 3              None  normal rl03 back of house rl03 z1 corridor mcp...
# 4              None  device missing node 1 ffcp modules eaf-b01-1 s...
#
#           detector                         notification  \
# 0  Z109N9L26D172S0  z109n9l26d172s0 - m214 - SC1 retail
# 1  Z102N9L26D191S0  z102n9l26d191s0 - m214 - SC1 retail
# 2   Z191N5L13D92S0   z191n5l13d92s0 - m214 - SC1 retail
# 3  Z109N9L26D172S0  z109n9l26d172s0 - SC1 retail - m214
# 4   Z801N1L3D136S0   z801n1l3d136s0 - m214 - SC1 retail
#
#                                                  raw state
# 0  initialising rl03 back of house rl03 z1 corrid...  NNNN
# 1        normal rl03 smoke zone 2 rl03 sz2 s3016 ysl  NNNN
# 2  device missing rl06 smoke zone 1 rl06 sz1 77c ...  ??F?
# 3  normal rl03 back of house rl03 z1 corridor mcp...  NNNN
# 4  device missing node 1 ffcp modules eaf-b01-1 s...  ??F?
#
# [5 rows x 30 columns]

# %%
print(df.shape)
# Out:
# (940083, 30)

# %%
df['DURATION'] = df['DURATION'].fillna('{}')

# %%
print(df['DURATION'].dtype)
print(df['DURATION'].head())
# Out:
# object
# 0    {}
# 1    {}
# 2    {}
# 3    {}
# 4    {}
# Name: DURATION, dtype: object

# %%
df_duration_expanded = df['DURATION'].apply(json.loads).apply(pd.Series, dtype='object')

# %%
#Rename columns with a prefix
df_duration_expanded = df_duration_expanded.rename(columns=lambda x: f'duration_{x}')

# %%
df = df.join(df_duration_expanded)

# %%
print (df.shape)
df.head()
# Out:
# (940083, 34)
#                   ADDEDAT             COMPANYID            DETECTORID  \
# 0 2024-08-07 17:56:29.842  n7Tktl6xJA2qDV8RcMpf  NflPelhGxDx2yF20gn7Y
# 1 2024-08-14 10:49:42.359  n7Tktl6xJA2qDV8RcMpf  yPHI0SRu7cRZ2YNmfDPG
# 2 2024-09-03 17:05:31.186  n7Tktl6xJA2qDV8RcMpf  hsBtiG1y58ChVue6Mstj
# 3 2025-01-09 03:27:26.923  n7Tktl6xJA2qDV8RcMpf  NflPelhGxDx2yF20gn7Y
# 4 2024-08-28 12:18:26.508  n7Tktl6xJA2qDV8RcMpf  5r2EosP2Vnb9cMJsQUA9
#
#   DURATION                    ID  \
# 0       {}  O0uFfYqPcl4PMU3uXxpe
# 1       {}  xByYZSjb4uJqpLZkLwCa
# 2       {}  EEL0bHavix9GmwdKvd0p
# 3       {}  4RVo9ZSGMWFzHhvtUDcd
# 4       {}  91S1PYh6HlGxdBqqMf9S
#
#                                           IDENTIFIER              RECORDEDAT  \
# 0  {\n  "device": "172",\n  "group": null,\n  "lo... 2024-08-07 17:56:28.957
# 1  {\n  "device": "191",\n  "group": null,\n  "lo... 2024-08-14 10:49:40.278
# 2  {\n  "device": "92",\n  "group": null,\n  "loo... 2024-09-03 17:05:16.008
# 3  {\n  "device": "172",\n  "group": null,\n  "lo... 2025-01-09 03:27:24.867
# 4  {\n  "device": "136",\n  "group": null,\n  "lo... 2024-08-28 12:18:25.776
#
#                  SITEID                                              STATE  \
# 0  DO05xnc9uzEwZ1OvRGSP  {\n  "alarm": "off",\n  "fault": "off",\n  "fa...
# 1  DO05xnc9uzEwZ1OvRGSP  {\n  "alarm": "off",\n  "fault": "off",\n  "fa...
# 2  DO05xnc9uzEwZ1OvRGSP  {\n  "alarm": "unknown",\n  "fault": "on",\n  ...
# 3  DO05xnc9uzEwZ1OvRGSP  {\n  "alarm": "off",\n  "fault": "off",\n  "fa...
# 4  DO05xnc9uzEwZ1OvRGSP  {\n  "alarm": "unknown",\n  "fault": "on",\n  ...
#
#    SYSTEMGENERATED  ...  sensor_from_state  \
# 0            False  ...               None
# 1            False  ...               None
# 2            False  ...               None
# 3            False  ...               None
# 4            False  ...               None
#
#                                           descriptor         detector  \
# 0  initialising rl03 back of house rl03 z1 corrid...  Z109N9L26D172S0
# 1        normal rl03 smoke zone 2 rl03 sz2 s3016 ysl  Z102N9L26D191S0
# 2  device missing rl06 smoke zone 1 rl06 sz1 77c ...   Z191N5L13D92S0
# 3  normal rl03 back of house rl03 z1 corridor mcp...  Z109N9L26D172S0
# 4  device missing node 1 ffcp modules eaf-b01-1 s...   Z801N1L3D136S0
#
#                           notification  \
# 0  z109n9l26d172s0 - m214 - SC1 retail
# 1  z102n9l26d191s0 - m214 - SC1 retail
# 2   z191n5l13d92s0 - m214 - SC1 retail
# 3  z109n9l26d172s0 - SC1 retail - m214
# 4   z801n1l3d136s0 - m214 - SC1 retail
#
#                                                  raw state duration_alarm  \
# 0  initialising rl03 back of house rl03 z1 corrid...  NNNN            NaN
# 1        normal rl03 smoke zone 2 rl03 sz2 s3016 ysl  NNNN            NaN
# 2  device missing rl06 smoke zone 1 rl06 sz1 77c ...  ??F?            NaN
# 3  normal rl03 back of house rl03 z1 corridor mcp...  NNNN            NaN
# 4  device missing node 1 ffcp modules eaf-b01-1 s...  ??F?            NaN
#
#   duration_fault duration_isolate duration_preAlarm
# 0            NaN              NaN               NaN
# 1            NaN              NaN               NaN
# 2            NaN              NaN               NaN
# 3            NaN              NaN               NaN
# 4            NaN              NaN               NaN
#
# [5 rows x 34 columns]

# %%
df.loc[2, 'state']
# Out:
# '??F?'

# %%
df.loc[2, 'state']
# Out:
# '??F?'

# %%
df['duration_isolate']
# Out:
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
#             ...
# 940078         NaN
# 940079         NaN
# 940080         NaN
# 940081    PT0.328S
# 940082        None
# Name: duration_isolate, Length: 940083, dtype: object

# %%
# !pip install isodate
# Out:
# Requirement already satisfied: isodate in c:\users\user\anaconda3\lib\site-packages (0.7.2)

# %%
from isodate import parse_duration
def safe_parse_duration(x):
    try:
        if pd.isnull(x):
            return pd.NaT
        return parse_duration(x)
    except:
        return pd.NaT
df['duration_isolate'] = df['duration_isolate'].apply(safe_parse_duration)

# %%
df['duration_isolate']
# Out:
# 0                           NaT
# 1                           NaT
# 2                           NaT
# 3                           NaT
# 4                           NaT
#                   ...
# 940078                      NaT
# 940079                      NaT
# 940080                      NaT
# 940081   0 days 00:00:00.328000
# 940082                      NaT
# Name: duration_isolate, Length: 940083, dtype: timedelta64[ns]

# %%
df.head()
# Out:
#                   ADDEDAT             COMPANYID            DETECTORID  \
# 0 2024-08-07 17:56:29.842  n7Tktl6xJA2qDV8RcMpf  NflPelhGxDx2yF20gn7Y
# 1 2024-08-14 10:49:42.359  n7Tktl6xJA2qDV8RcMpf  yPHI0SRu7cRZ2YNmfDPG
# 2 2024-09-03 17:05:31.186  n7Tktl6xJA2qDV8RcMpf  hsBtiG1y58ChVue6Mstj
# 3 2025-01-09 03:27:26.923  n7Tktl6xJA2qDV8RcMpf  NflPelhGxDx2yF20gn7Y
# 4 2024-08-28 12:18:26.508  n7Tktl6xJA2qDV8RcMpf  5r2EosP2Vnb9cMJsQUA9
#
#   DURATION                    ID  \
# 0       {}  O0uFfYqPcl4PMU3uXxpe
# 1       {}  xByYZSjb4uJqpLZkLwCa
# 2       {}  EEL0bHavix9GmwdKvd0p
# 3       {}  4RVo9ZSGMWFzHhvtUDcd
# 4       {}  91S1PYh6HlGxdBqqMf9S
#
#                                           IDENTIFIER              RECORDEDAT  \
# 0  {\n  "device": "172",\n  "group": null,\n  "lo... 2024-08-07 17:56:28.957
# 1  {\n  "device": "191",\n  "group": null,\n  "lo... 2024-08-14 10:49:40.278
# 2  {\n  "device": "92",\n  "group": null,\n  "loo... 2024-09-03 17:05:16.008
# 3  {\n  "device": "172",\n  "group": null,\n  "lo... 2025-01-09 03:27:24.867
# 4  {\n  "device": "136",\n  "group": null,\n  "lo... 2024-08-28 12:18:25.776
#
#                  SITEID                                              STATE  \
# 0  DO05xnc9uzEwZ1OvRGSP  {\n  "alarm": "off",\n  "fault": "off",\n  "fa...
# 1  DO05xnc9uzEwZ1OvRGSP  {\n  "alarm": "off",\n  "fault": "off",\n  "fa...
# 2  DO05xnc9uzEwZ1OvRGSP  {\n  "alarm": "unknown",\n  "fault": "on",\n  ...
# 3  DO05xnc9uzEwZ1OvRGSP  {\n  "alarm": "off",\n  "fault": "off",\n  "fa...
# 4  DO05xnc9uzEwZ1OvRGSP  {\n  "alarm": "unknown",\n  "fault": "on",\n  ...
#
#    SYSTEMGENERATED  ...  sensor_from_state  \
# 0            False  ...               None
# 1            False  ...               None
# 2            False  ...               None
# 3            False  ...               None
# 4            False  ...               None
#
#                                           descriptor         detector  \
# 0  initialising rl03 back of house rl03 z1 corrid...  Z109N9L26D172S0
# 1        normal rl03 smoke zone 2 rl03 sz2 s3016 ysl  Z102N9L26D191S0
# 2  device missing rl06 smoke zone 1 rl06 sz1 77c ...   Z191N5L13D92S0
# 3  normal rl03 back of house rl03 z1 corridor mcp...  Z109N9L26D172S0
# 4  device missing node 1 ffcp modules eaf-b01-1 s...   Z801N1L3D136S0
#
#                           notification  \
# 0  z109n9l26d172s0 - m214 - SC1 retail
# 1  z102n9l26d191s0 - m214 - SC1 retail
# 2   z191n5l13d92s0 - m214 - SC1 retail
# 3  z109n9l26d172s0 - SC1 retail - m214
# 4   z801n1l3d136s0 - m214 - SC1 retail
#
#                                                  raw state duration_alarm  \
# 0  initialising rl03 back of house rl03 z1 corrid...  NNNN            NaN
# 1        normal rl03 smoke zone 2 rl03 sz2 s3016 ysl  NNNN            NaN
# 2  device missing rl06 smoke zone 1 rl06 sz1 77c ...  ??F?            NaN
# 3  normal rl03 back of house rl03 z1 corridor mcp...  NNNN            NaN
# 4  device missing node 1 ffcp modules eaf-b01-1 s...  ??F?            NaN
#
#   duration_fault duration_isolate duration_preAlarm
# 0            NaN              NaT               NaN
# 1            NaN              NaT               NaN
# 2            NaN              NaT               NaN
# 3            NaN              NaT               NaN
# 4            NaN              NaT               NaN
#
# [5 rows x 34 columns]

# %%
del df['STATE']
del df['IDENTIFIER']
del df['MESSAGE']

# %%
df.head()
# Out:
#                   ADDEDAT             COMPANYID            DETECTORID  \
# 0 2024-08-07 17:56:29.842  n7Tktl6xJA2qDV8RcMpf  NflPelhGxDx2yF20gn7Y
# 1 2024-08-14 10:49:42.359  n7Tktl6xJA2qDV8RcMpf  yPHI0SRu7cRZ2YNmfDPG
# 2 2024-09-03 17:05:31.186  n7Tktl6xJA2qDV8RcMpf  hsBtiG1y58ChVue6Mstj
# 3 2025-01-09 03:27:26.923  n7Tktl6xJA2qDV8RcMpf  NflPelhGxDx2yF20gn7Y
# 4 2024-08-28 12:18:26.508  n7Tktl6xJA2qDV8RcMpf  5r2EosP2Vnb9cMJsQUA9
#
#   DURATION                    ID              RECORDEDAT  \
# 0       {}  O0uFfYqPcl4PMU3uXxpe 2024-08-07 17:56:28.957
# 1       {}  xByYZSjb4uJqpLZkLwCa 2024-08-14 10:49:40.278
# 2       {}  EEL0bHavix9GmwdKvd0p 2024-09-03 17:05:16.008
# 3       {}  4RVo9ZSGMWFzHhvtUDcd 2025-01-09 03:27:24.867
# 4       {}  91S1PYh6HlGxdBqqMf9S 2024-08-28 12:18:25.776
#
#                  SITEID  SYSTEMGENERATED  WILLSHOWINAPP device  ...  \
# 0  DO05xnc9uzEwZ1OvRGSP            False           True    172  ...
# 1  DO05xnc9uzEwZ1OvRGSP            False           True    191  ...
# 2  DO05xnc9uzEwZ1OvRGSP            False           True     92  ...
# 3  DO05xnc9uzEwZ1OvRGSP            False           True    172  ...
# 4  DO05xnc9uzEwZ1OvRGSP            False           True    136  ...
#
#   sensor_from_state                                         descriptor  \
# 0              None  initialising rl03 back of house rl03 z1 corrid...
# 1              None        normal rl03 smoke zone 2 rl03 sz2 s3016 ysl
# 2              None  device missing rl06 smoke zone 1 rl06 sz1 77c ...
# 3              None  normal rl03 back of house rl03 z1 corridor mcp...
# 4              None  device missing node 1 ffcp modules eaf-b01-1 s...
#
#           detector                         notification  \
# 0  Z109N9L26D172S0  z109n9l26d172s0 - m214 - SC1 retail
# 1  Z102N9L26D191S0  z102n9l26d191s0 - m214 - SC1 retail
# 2   Z191N5L13D92S0   z191n5l13d92s0 - m214 - SC1 retail
# 3  Z109N9L26D172S0  z109n9l26d172s0 - SC1 retail - m214
# 4   Z801N1L3D136S0   z801n1l3d136s0 - m214 - SC1 retail
#
#                                                  raw state duration_alarm  \
# 0  initialising rl03 back of house rl03 z1 corrid...  NNNN            NaN
# 1        normal rl03 smoke zone 2 rl03 sz2 s3016 ysl  NNNN            NaN
# 2  device missing rl06 smoke zone 1 rl06 sz1 77c ...  ??F?            NaN
# 3  normal rl03 back of house rl03 z1 corridor mcp...  NNNN            NaN
# 4  device missing node 1 ffcp modules eaf-b01-1 s...  ??F?            NaN
#
#   duration_fault duration_isolate duration_preAlarm
# 0            NaN              NaT               NaN
# 1            NaN              NaT               NaN
# 2            NaN              NaT               NaN
# 3            NaN              NaT               NaN
# 4            NaN              NaT               NaN
#
# [5 rows x 31 columns]

# %%
df['faultCode']
# Out:
# 0                                                      None
# 1                                                      None
# 2            {'panel': 'AXIS', 'text': None, 'value': None}
# 3                                                      None
# 4            {'panel': 'AXIS', 'text': None, 'value': None}
#                                 ...
# 940078    {'panel': 'SIMPLEX', 'text': None, 'value': None}
# 940079    {'panel': 'SIMPLEX', 'text': None, 'value': None}
# 940080    {'panel': 'SIMPLEX', 'text': None, 'value': None}
# 940081                                                 None
# 940082                                                 None
# Name: faultCode, Length: 940083, dtype: object

# %%
# Step 2: Convert JSON string to Python dict
df_json = df['DURATION'].fillna('{}').apply(json.loads)

# Step 3: Extract 'isolate' using safe .get()
df['duration_isolate'] = df_json.apply(lambda x: x.get('isolate'))

# %%
# Step 4: Safe parse
def safe_parse_duration(x):
    try:
        if pd.isnull(x):
            return pd.NaT
        return parse_duration(x)
    except:
        return pd.NaT

# Step 5: Apply parsing
df['duration_isolate'] = df['duration_isolate'].apply(safe_parse_duration)

# %%
print(df['duration_isolate'].notna().sum(), "parsed durations")
print(df['duration_isolate'].unique())
# Out:
# 116795 parsed durations
# [          'NaT' 174968573000000 604938119000000 ... 120254947000000
#   22186931000000   9624483000000]

# %%
print(df['duration_isolate'].head(20))
# Out:
# 0                       NaT
# 1                       NaT
# 2                       NaT
# 3                       NaT
# 4                       NaT
# 5                       NaT
# 6                       NaT
# 7                       NaT
# 8                       NaT
# 9                       NaT
# 10                      NaT
# 11                      NaT
# 12                      NaT
# 13                      NaT
# 14                      NaT
# 15   2 days 00:36:08.573000
# 16                      NaT
# 17                      NaT
# 18                      NaT
# 19                      NaT
# Name: duration_isolate, dtype: timedelta64[ns]

# %%
# Step 2: Convert JSON string to Python dict
df_json = df['DURATION'].fillna('{}').apply(json.loads)

# Step 3: Extract 'isolate' using safe .get()
df['duration_alarm'] = df_json.apply(lambda x: x.get('alarm'))

# %%
# Step 4: Safe parse
def safe_parse_duration(x):
    try:
        if pd.isnull(x):
            return pd.NaT
        return parse_duration(x)
    except:
        return pd.NaT

# Step 5: Apply parsing
df['duration_alarm'] = df['duration_alarm'].apply(safe_parse_duration)

# %%
print(df['duration_alarm'].notna().sum(), "parsed durations")
print(df['duration_alarm'].unique())
# Out:
# 3062 parsed durations
# [       'NaT' 299983000000 534424000000 ... 146212000000  50137000000
#  188848000000]

# %%
df[df['duration_alarm'].notna()].head()
# Out:
#                      ADDEDAT             COMPANYID            DETECTORID  \
# 208  2025-01-18 02:03:29.814  n7Tktl6xJA2qDV8RcMpf  KgoXC0AcdzVFkdSij5X3
# 386  2024-12-11 12:59:09.451  n7Tktl6xJA2qDV8RcMpf  aYonkgIQXXmwR7vl38JI
# 822  2025-01-22 04:03:18.843  n7Tktl6xJA2qDV8RcMpf  BDRlKbJKUui43SWY3Oez
# 962  2024-08-15 18:47:44.966  n7Tktl6xJA2qDV8RcMpf  aYonkgIQXXmwR7vl38JI
# 1047 2025-01-22 21:09:01.019  n7Tktl6xJA2qDV8RcMpf  VjnAcQNarNM8F0qlt9SE
#
#                                                DURATION                    ID  \
# 208   {\n  "alarm": "PT4M59.983S",\n  "fault": null,...  77JEVYiHkRp5Ly2mVuc3
# 386   {\n  "alarm": "PT8M54.424S",\n  "fault": null,...  Ie0f29pgNbkKT3Uk8vQy
# 822   {\n  "alarm": "PT33M52.3S",\n  "fault": null,\...  ct7OPlGLtwxkTEeMJQES
# 962   {\n  "alarm": "PT5M56.371S",\n  "fault": null,...  ujNACLSpFmtQa3bHYNyP
# 1047  {\n  "alarm": "PT37M9.309S",\n  "fault": null,...  UocPiY76Jq1oggseIVAB
#
#                   RECORDEDAT                SITEID  SYSTEMGENERATED  \
# 208  2025-01-18 02:03:14.104  DO05xnc9uzEwZ1OvRGSP            False
# 386  2024-12-11 12:59:07.225  DO05xnc9uzEwZ1OvRGSP            False
# 822  2025-01-22 04:03:18.173  DO05xnc9uzEwZ1OvRGSP            False
# 962  2024-08-15 18:47:44.009  DO05xnc9uzEwZ1OvRGSP            False
# 1047 2025-01-22 21:08:59.895  DO05xnc9uzEwZ1OvRGSP            False
#
#       WILLSHOWINAPP device  ... sensor_from_state  \
# 208            True     42  ...              None
# 386            True    118  ...              None
# 822            True     42  ...              None
# 962            True    118  ...              None
# 1047          False    117  ...              None
#
#                                              descriptor         detector  \
# 208   normal rl01 back of house rl01 electrical rm r...     Z49N1L2D42S0
# 386   normal sprinkler electric pump b01 z1 electric...   Z405N1L3D118S0
# 822     reset rl03 smoke zone 1 rl03 sz1 mall adj s3027   Z101N9L26D42S0
# 962   normal sprinkler electric pump b01 z1 electric...   Z405N1L3D118S0
# 1047    reset rl03 smoke zone 4 rl03 sz4 mall adj s3035  Z104N9L26D117S0
#
#                              notification  \
# 208      z49n1l2d42s0 - SC1 retail - m214
# 386    z405n1l3d118s0 - SC1 retail - m214
# 822    z101n9l26d42s0 - SC1 retail - m214
# 962    z405n1l3d118s0 - m214 - SC1 retail
# 1047  z104n9l26d117s0 - SC1 retail - m214
#
#                                                     raw state  \
# 208   normal rl01 back of house rl01 electrical rm r...  NNNN
# 386   normal sprinkler electric pump b01 z1 electric...  NNNN
# 822     reset rl03 smoke zone 1 rl03 sz1 mall adj s3027  NNNN
# 962   normal sprinkler electric pump b01 z1 electric...  NNNN
# 1047    reset rl03 smoke zone 4 rl03 sz4 mall adj s3035  NNNN
#
#              duration_alarm duration_fault duration_isolate duration_preAlarm
# 208  0 days 00:04:59.983000           None              NaT              None
# 386  0 days 00:08:54.424000           None              NaT              None
# 822  0 days 00:33:52.300000           None              NaT              None
# 962  0 days 00:05:56.371000           None              NaT              None
# 1047 0 days 00:37:09.309000           None              NaT              None
#
# [5 rows x 31 columns]

# %%
# Step 2: Convert JSON string to Python dict
df_json = df['DURATION'].fillna('{}').apply(json.loads)

# Step 3: Extract 'isolate' using safe .get()
df['duration_preAlarm'] = df_json.apply(lambda x: x.get('preAlarm'))

# %%
# Step 4: Safe parse
def safe_parse_duration(x):
    try:
        if pd.isnull(x):
            return pd.NaT
        return parse_duration(x)
    except:
        return pd.NaT

# Step 5: Apply parsing
df['duration_preAlarm'] = df['duration_preAlarm'].apply(safe_parse_duration)

# %%
df[df['duration_preAlarm'].notna()].head()
# Out:
#                       ADDEDAT             COMPANYID            DETECTORID  \
# 4933  2025-01-15 01:31:28.534  n7Tktl6xJA2qDV8RcMpf  voMInBJtPE3z26BFhBSb
# 5530  2025-01-14 22:46:15.887  n7Tktl6xJA2qDV8RcMpf  i3mnEx3qA3Ib61cTCvFP
# 8670  2025-01-23 23:20:01.998  n7Tktl6xJA2qDV8RcMpf  7VteXSDOnOyBkenECFmL
# 10153 2025-01-23 21:54:17.961  n7Tktl6xJA2qDV8RcMpf  P4RsvKFfiS7LFObhgr4D
# 11660 2025-01-17 23:52:04.023  n7Tktl6xJA2qDV8RcMpf  H3X3mbBsA8sz8QBAPfZ5
#
#                                                 DURATION  \
# 4933   {\n  "alarm": null,\n  "fault": null,\n  "isol...
# 5530   {\n  "alarm": null,\n  "fault": null,\n  "isol...
# 8670   {\n  "alarm": "PT0.888S",\n  "fault": null,\n ...
# 10153  {\n  "alarm": "PT23M10.801S",\n  "fault": null...
# 11660  {\n  "alarm": "PT9.373S",\n  "fault": null,\n ...
#
#                          ID              RECORDEDAT                SITEID  \
# 4933   UvqRTauMTZYbZCZxkead 2025-01-15 01:31:27.439  DO05xnc9uzEwZ1OvRGSP
# 5530   PUhyERXMKp0hneCZrHCY 2025-01-14 22:46:15.081  DO05xnc9uzEwZ1OvRGSP
# 8670   WVxrazA8HXltQAyWF3Y7 2025-01-23 23:20:00.347  DO05xnc9uzEwZ1OvRGSP
# 10153  In9JSfJbs3wwO1xQ6iec 2025-01-23 21:54:16.946  DO05xnc9uzEwZ1OvRGSP
# 11660  CGnr6KKwZjot37QY83dt 2025-01-17 23:52:03.204  DO05xnc9uzEwZ1OvRGSP
#
#        SYSTEMGENERATED  WILLSHOWINAPP device  ... sensor_from_state  \
# 4933             False           True    147  ...              None
# 5530             False           True      4  ...              None
# 8670             False           True    125  ...              None
# 10153            False           True     11  ...              None
# 11660            False           True    154  ...              None
#
#                                               descriptor         detector  \
# 4933   normal rl02 smoke zone 1 rl02 sz1 s2026a swaro...    Z71N6L6D147S0
# 5530   normal node 4 ffcp modules rl08 ahu 6001 duct ...    Z804N4L16D4S0
# 8670                            normal rl03 smoke zone 4  Z104N9L25D125S0
# 10153  reset rl02 back of house rl02 z2 gucci boh sto...     Z79N6L5D11S0
# 11660                           normal rl06 smoke zone 1  Z194N5L13D154S0
#
#                               notification  \
# 4933     z71n6l6d147s0 - SC1 retail - m214
# 5530     z804n4l16d4s0 - SC1 retail - m214
# 8670   z104n9l25d125s0 - SC1 retail - m214
# 10153     z79n6l5d11s0 - SC1 retail - m214
# 11660  z194n5l13d154s0 - SC1 retail - m214
#
#                                                      raw state  \
# 4933   normal rl02 smoke zone 1 rl02 sz1 s2026a swaro...  NNNN
# 5530   normal node 4 ffcp modules rl08 ahu 6001 duct ...  NNNN
# 8670                            normal rl03 smoke zone 4  NNNN
# 10153  reset rl02 back of house rl02 z2 gucci boh sto...  NNNN
# 11660                           normal rl06 smoke zone 1  NNNN
#
#               duration_alarm duration_fault duration_isolate  \
# 4933                     NaT           None              NaT
# 5530                     NaT           None              NaT
# 8670  0 days 00:00:00.888000           None              NaT
# 10153 0 days 00:23:10.801000           None              NaT
# 11660 0 days 00:00:09.373000           None              NaT
#
#            duration_preAlarm
# 4933  0 days 00:00:33.864000
# 5530  0 days 00:12:48.740000
# 8670  0 days 00:00:25.066000
# 10153 0 days 00:23:31.090000
# 11660 0 days 00:00:27.948000
#
# [5 rows x 31 columns]

# %%
# Timestamp conversion
df['ADDEDAT'] = pd.to_datetime(df['ADDEDAT'], errors='coerce')

# %%
df['RECORDEDAT'] = pd.to_datetime(df['RECORDEDAT'], errors='coerce')

# %%
df.head(10)
# Out:
#                   ADDEDAT             COMPANYID            DETECTORID  \
# 0 2024-08-07 17:56:29.842  n7Tktl6xJA2qDV8RcMpf  NflPelhGxDx2yF20gn7Y
# 1 2024-08-14 10:49:42.359  n7Tktl6xJA2qDV8RcMpf  yPHI0SRu7cRZ2YNmfDPG
# 2 2024-09-03 17:05:31.186  n7Tktl6xJA2qDV8RcMpf  hsBtiG1y58ChVue6Mstj
# 3 2025-01-09 03:27:26.923  n7Tktl6xJA2qDV8RcMpf  NflPelhGxDx2yF20gn7Y
# 4 2024-08-28 12:18:26.508  n7Tktl6xJA2qDV8RcMpf  5r2EosP2Vnb9cMJsQUA9
# 5 2024-07-23 20:41:19.217  n7Tktl6xJA2qDV8RcMpf  NflPelhGxDx2yF20gn7Y
# 6 2024-12-11 02:38:35.703  n7Tktl6xJA2qDV8RcMpf  NflPelhGxDx2yF20gn7Y
# 7 2024-11-06 16:15:09.196  n7Tktl6xJA2qDV8RcMpf  C29g2RaN96YNvHFaLpiE
# 8 2024-09-10 22:24:11.867  n7Tktl6xJA2qDV8RcMpf  8hQnV3aU7CaTupG0w389
# 9 2024-08-11 17:10:44.711  n7Tktl6xJA2qDV8RcMpf  nSHXqKSwHbGZjNi6GYEJ
#
#   DURATION                    ID              RECORDEDAT  \
# 0       {}  O0uFfYqPcl4PMU3uXxpe 2024-08-07 17:56:28.957
# 1       {}  xByYZSjb4uJqpLZkLwCa 2024-08-14 10:49:40.278
# 2       {}  EEL0bHavix9GmwdKvd0p 2024-09-03 17:05:16.008
# 3       {}  4RVo9ZSGMWFzHhvtUDcd 2025-01-09 03:27:24.867
# 4       {}  91S1PYh6HlGxdBqqMf9S 2024-08-28 12:18:25.776
# 5       {}  i3nf8E4FxlMW1ZzOy1h0 2024-07-23 20:41:17.453
# 6       {}  TnXI50CNHrOJnPRkUWlu 2024-12-11 02:38:34.384
# 7       {}  tWM6FMeNqljcdcavheuO 2024-11-06 16:15:08.310
# 8       {}  gcEyBbBoj5dh8kirqCSy 2024-09-10 22:24:11.867
# 9       {}  IAB0C9HOKcT7zcBOOw9o 2024-08-11 17:10:34.232
#
#                  SITEID  SYSTEMGENERATED  WILLSHOWINAPP device  ...  \
# 0  DO05xnc9uzEwZ1OvRGSP            False           True    172  ...
# 1  DO05xnc9uzEwZ1OvRGSP            False           True    191  ...
# 2  DO05xnc9uzEwZ1OvRGSP            False           True     92  ...
# 3  DO05xnc9uzEwZ1OvRGSP            False           True    172  ...
# 4  DO05xnc9uzEwZ1OvRGSP            False           True    136  ...
# 5  DO05xnc9uzEwZ1OvRGSP            False           True    172  ...
# 6  DO05xnc9uzEwZ1OvRGSP            False           True    172  ...
# 7  DO05xnc9uzEwZ1OvRGSP            False           True   None  ...
# 8  DO05xnc9uzEwZ1OvRGSP             True           True    195  ...
# 9  DO05xnc9uzEwZ1OvRGSP            False           True     30  ...
#
#                                    sensor_from_state  \
# 0                                               None
# 1                                               None
# 2                                               None
# 3                                               None
# 4                                               None
# 5                                               None
# 6                                               None
# 7                                               None
# 8  {'maximum': None, 'minimum': None, 'normal': N...
# 9                                               None
#
#                                           descriptor         detector  \
# 0  initialising rl03 back of house rl03 z1 corrid...  Z109N9L26D172S0
# 1        normal rl03 smoke zone 2 rl03 sz2 s3016 ysl  Z102N9L26D191S0
# 2  device missing rl06 smoke zone 1 rl06 sz1 77c ...   Z191N5L13D92S0
# 3  normal rl03 back of house rl03 z1 corridor mcp...  Z109N9L26D172S0
# 4  device missing node 1 ffcp modules eaf-b01-1 s...   Z801N1L3D136S0
# 5  initialising rl03 back of house rl03 z1 corrid...  Z109N9L26D172S0
# 6  initialising rl03 back of house rl03 z1 corrid...  Z109N9L26D172S0
# 7                                               mute          Z923N23
# 8                               active event expiry     Z44N1L2D195S0
# 9                           normal rl04 smoke zone 3   Z133N9L23D30S0
#
#                                      notification  \
# 0             z109n9l26d172s0 - m214 - SC1 retail
# 1             z102n9l26d191s0 - m214 - SC1 retail
# 2              z191n5l13d92s0 - m214 - SC1 retail
# 3             z109n9l26d172s0 - SC1 retail - m214
# 4              z801n1l3d136s0 - m214 - SC1 retail
# 5             z109n9l26d172s0 - m214 - SC1 retail
# 6             z109n9l26d172s0 - SC1 retail - m214
# 7                     z923n23 - SC1 retail - m214
# 8  detector id: z44n1l2d195s0 - m214 - SC1 retail
# 9              z133n9l23d30s0 - m214 - SC1 retail
#
#                                                  raw state duration_alarm  \
# 0  initialising rl03 back of house rl03 z1 corrid...  NNNN            NaT
# 1        normal rl03 smoke zone 2 rl03 sz2 s3016 ysl  NNNN            NaT
# 2  device missing rl06 smoke zone 1 rl06 sz1 77c ...  ??F?            NaT
# 3  normal rl03 back of house rl03 z1 corridor mcp...  NNNN            NaT
# 4  device missing node 1 ffcp modules eaf-b01-1 s...  ??F?            NaT
# 5  initialising rl03 back of house rl03 z1 corrid...  NNNN            NaT
# 6  initialising rl03 back of house rl03 z1 corrid...  NNNN            NaT
# 7                                               mute  ???I            NaT
# 8             ???nz44n1l2d195s0 active event expiry   ???N            NaT
# 9                           normal rl04 smoke zone 3  NNNN            NaT
#
#   duration_fault duration_isolate duration_preAlarm
# 0            NaN              NaT               NaT
# 1            NaN              NaT               NaT
# 2            NaN              NaT               NaT
# 3            NaN              NaT               NaT
# 4            NaN              NaT               NaT
# 5            NaN              NaT               NaT
# 6            NaN              NaT               NaT
# 7            NaN              NaT               NaT
# 8            NaN              NaT               NaT
# 9            NaN              NaT               NaT
#
# [10 rows x 31 columns]

# %%
# Check for missing timestamps (NaT)
print(df['ADDEDAT'].isna().sum(), "missing timestamps")

# Check the first few rows to verify timestamp format
print(df['ADDEDAT'].head())

# Check for invalid timestamps (NaT or outliers)
print(df['ADDEDAT'].describe())
# Out:
# 0 missing timestamps
# 0   2024-08-07 17:56:29.842
# 1   2024-08-14 10:49:42.359
# 2   2024-09-03 17:05:31.186
# 3   2025-01-09 03:27:26.923
# 4   2024-08-28 12:18:26.508
# Name: ADDEDAT, dtype: datetime64[ns]
# count                         940083
# unique                        938202
# top       2024-07-31 06:44:16.954000
# freq                             421
# first     2024-07-10 01:07:06.668000
# last      2025-03-10 19:41:54.640000
# Name: ADDEDAT, dtype: object
# C:\Users\User\AppData\Local\Temp\ipykernel_11800\685933736.py:8: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   print(df['ADDEDAT'].describe())

# %%
# ISO conversion of Duration_fault
#: Extract 'fault' using safe .get()
df['duration_fault'] = df_json.apply(lambda x: x.get('fault'))

# %%
# Step 4: Safe parse
def safe_parse_duration(x):
    try:
        if pd.isnull(x):
            return pd.NaT
        return parse_duration(x)
    except:
        return pd.NaT

# Step 5: Apply parsing
df['duration_fault'] = df['duration_fault'].apply(safe_parse_duration)

# %%
print(df['duration_fault'].notna().sum(), "parsed durations")
print(df['duration_fault'].unique())
# Out:
# 174226 parsed durations
# [          'NaT' 604860610000000   1726313000000 ... 120252943000000
#   22184715000000   9627810000000]

# %%
# verify all the ISO are converted successfully
cols = ['duration_preAlarm', 'duration_fault', 'duration_alarm', 'duration_isolate']
df[cols][df[cols].notna().any(axis=1)].head()
# Out:
#    duration_preAlarm         duration_fault duration_alarm  \
# 15               NaT                    NaT            NaT
# 25               NaT                    NaT            NaT
# 30               NaT 7 days 00:01:00.610000            NaT
# 48               NaT                    NaT            NaT
# 61               NaT                    NaT            NaT
#
#          duration_isolate
# 15 2 days 00:36:08.573000
# 25 7 days 00:02:18.119000
# 30                    NaT
# 48 7 days 00:02:14.636000
# 61 7 days 00:02:10.895000

# %%
df.head()
# Out:
#                   ADDEDAT             COMPANYID            DETECTORID  \
# 0 2024-08-07 17:56:29.842  n7Tktl6xJA2qDV8RcMpf  NflPelhGxDx2yF20gn7Y
# 1 2024-08-14 10:49:42.359  n7Tktl6xJA2qDV8RcMpf  yPHI0SRu7cRZ2YNmfDPG
# 2 2024-09-03 17:05:31.186  n7Tktl6xJA2qDV8RcMpf  hsBtiG1y58ChVue6Mstj
# 3 2025-01-09 03:27:26.923  n7Tktl6xJA2qDV8RcMpf  NflPelhGxDx2yF20gn7Y
# 4 2024-08-28 12:18:26.508  n7Tktl6xJA2qDV8RcMpf  5r2EosP2Vnb9cMJsQUA9
#
#   DURATION                    ID              RECORDEDAT  \
# 0       {}  O0uFfYqPcl4PMU3uXxpe 2024-08-07 17:56:28.957
# 1       {}  xByYZSjb4uJqpLZkLwCa 2024-08-14 10:49:40.278
# 2       {}  EEL0bHavix9GmwdKvd0p 2024-09-03 17:05:16.008
# 3       {}  4RVo9ZSGMWFzHhvtUDcd 2025-01-09 03:27:24.867
# 4       {}  91S1PYh6HlGxdBqqMf9S 2024-08-28 12:18:25.776
#
#                  SITEID  SYSTEMGENERATED  WILLSHOWINAPP device  ...  \
# 0  DO05xnc9uzEwZ1OvRGSP            False           True    172  ...
# 1  DO05xnc9uzEwZ1OvRGSP            False           True    191  ...
# 2  DO05xnc9uzEwZ1OvRGSP            False           True     92  ...
# 3  DO05xnc9uzEwZ1OvRGSP            False           True    172  ...
# 4  DO05xnc9uzEwZ1OvRGSP            False           True    136  ...
#
#   sensor_from_state                                         descriptor  \
# 0              None  initialising rl03 back of house rl03 z1 corrid...
# 1              None        normal rl03 smoke zone 2 rl03 sz2 s3016 ysl
# 2              None  device missing rl06 smoke zone 1 rl06 sz1 77c ...
# 3              None  normal rl03 back of house rl03 z1 corridor mcp...
# 4              None  device missing node 1 ffcp modules eaf-b01-1 s...
#
#           detector                         notification  \
# 0  Z109N9L26D172S0  z109n9l26d172s0 - m214 - SC1 retail
# 1  Z102N9L26D191S0  z102n9l26d191s0 - m214 - SC1 retail
# 2   Z191N5L13D92S0   z191n5l13d92s0 - m214 - SC1 retail
# 3  Z109N9L26D172S0  z109n9l26d172s0 - SC1 retail - m214
# 4   Z801N1L3D136S0   z801n1l3d136s0 - m214 - SC1 retail
#
#                                                  raw state duration_alarm  \
# 0  initialising rl03 back of house rl03 z1 corrid...  NNNN            NaT
# 1        normal rl03 smoke zone 2 rl03 sz2 s3016 ysl  NNNN            NaT
# 2  device missing rl06 smoke zone 1 rl06 sz1 77c ...  ??F?            NaT
# 3  normal rl03 back of house rl03 z1 corridor mcp...  NNNN            NaT
# 4  device missing node 1 ffcp modules eaf-b01-1 s...  ??F?            NaT
#
#   duration_fault duration_isolate duration_preAlarm
# 0            NaT              NaT               NaT
# 1            NaT              NaT               NaT
# 2            NaT              NaT               NaT
# 3            NaT              NaT               NaT
# 4            NaT              NaT               NaT
#
# [5 rows x 31 columns]

# %%
# Save DataFrame as a CSV file
df.to_csv('Fire_Events_Data_Cleaned.csv', index=False)
